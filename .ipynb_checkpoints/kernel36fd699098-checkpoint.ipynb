# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 
from IPython.core.display import display, HTML

import base64
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from google.cloud import bigquery
from bq_helper import BigQueryHelper

def create_download_link(df, title = "Download CSV file", filename = "data.csv"):  
    csv = df.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)


bq_assistant = BigQueryHelper("patents-public-data", "google_patents_research")
# bq_assistant.list_tables()
client = bigquery.Client()
# display(create_download_link(publication_df))

# %%
query = ('SELECT * FROM `patents-public-data.google_patents_research.publications` LIMIT 10')
query_job = client.query(query) 
query_job.to_dataframe()

# %%
query = ('SELECT * FROM `patents-public-data.google_patents_research.publications` where top_terms is not null LIMIT 5')
publication_job = client.query(query)
[job for job in publication_job]

# %%
query = ('SELECT * FROM `patents-public-data.patents.publications`  order by filing_date desc LIMIT 10')
filing_date_job = client.query(query)
[job for job in filing_date_job]

# %%
query = ('SELECT AVG(num_inventors), COUNT(*) AS cnt, country_code, filing_year, STRING_AGG(publication_number LIMIT 10) AS example_publications FROM (  SELECT ANY_VALUE(publication_number) AS publication_number, ANY_VALUE(ARRAY_LENGTH(inventor)) AS num_inventors, ANY_VALUE(country_code) AS country_code, ANY_VALUE(CAST(FLOOR(filing_date / (5*10000)) AS INT64))*5 AS filing_year   FROM `patents-public-data.patents.publications` AS pubs  WHERE filing_date > 19000000 AND ARRAY_LENGTH(inventor) > 0  GROUP BY application_number) GROUP BY filing_year, country_code HAVING cnt > 100 ORDER BY filing_year')
avg_job = client.query(query)
# [job for job in avg_job]
avg_inventor = avg_job.result().to_dataframe()

# %%
avg_inventor.plot()

# %%
count = avg_inventor['cnt'].tolist()
country_codes = avg_inventor['country_code'].tolist()

# %%
country_codes

# %%
import numpy as np                                                               
import matplotlib.pyplot as plt

ys = count
xs = country_codes

width = 10
plt.bar(xs, ys, width, align='center')
# plt.xticks(np.arange(len(country_codes)), xs) #Replace default x-ticks with xs, then replace xs with labels
plt.show()

# %%
query = 'select publication_date from `patents-public-data.patents.publications` order by publication_date desc limit 5;'
job = client.query(query)
job.result().to_dataframe()

# %%
query = 'select * from `patents-public-data.google_patents_research.publications` where ARRAY_LENGTH(top_terms) > 0 limit 1000'
job = client.query(query)
result = job.result().to_dataframe()
# Out:
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# /opt/conda/lib/python3.6/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     181         try:
# --> 182             return target()
#     183
#
# /root/.local/lib/python3.6/site-packages/kaggle_gcp.py in api_request(self, *args, **kwargs)
#      87         try:
# ---> 88             return super().api_request(*args, **kwargs)
#      89         except Forbidden as e:
#
# /opt/conda/lib/python3.6/site-packages/google/cloud/_http.py in api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object)
#     395         if not 200 <= response.status_code < 300:
# --> 396             raise exceptions.from_http_response(response)
#     397
#
# TooManyRequests: 429 POST https://dp.kaggle.net/bigquery/v2/projects/kaggle-161607/jobs: Quota exceeded
#
# The above exception was the direct cause of the following exception:
#
# RetryError                                Traceback (most recent call last)
# <ipython-input-96-567b0e739c15> in <module>
#       1 query = 'select top_terms from `patents-public-data.google_patents_research.publications` where ARRAY_LENGTH(top_terms) > 0 limit 10'
# ----> 2 job = client.query(query)
#       3 result = job.result().to_dataframe()
#
# /opt/conda/lib/python3.6/site-packages/google/cloud/bigquery/client.py in query(self, query, job_config, job_id, job_id_prefix, location, project, retry)
#    1652         job_ref = job._JobReference(job_id, project=project, location=location)
#    1653         query_job = job.QueryJob(job_ref, query, client=self, job_config=job_config)
# -> 1654         query_job._begin(retry=retry)
#    1655
#    1656         return query_job
#
# /opt/conda/lib/python3.6/site-packages/google/cloud/bigquery/job.py in _begin(self, client, retry)
#     580         # job has an ID.
#     581         api_response = client._call_api(
# --> 582             retry, method="POST", path=path, data=self.to_api_repr()
#     583         )
#     584         self._set_properties(api_response)
#
# /opt/conda/lib/python3.6/site-packages/google/cloud/bigquery/client.py in _call_api(self, retry, **kwargs)
#     411         if retry:
#     412             call = retry(call)
# --> 413         return call()
#     414
#     415     def get_dataset(self, dataset_ref, retry=DEFAULT_RETRY):
#
# /opt/conda/lib/python3.6/site-packages/google/api_core/retry.py in retry_wrapped_func(*args, **kwargs)
#     271                 sleep_generator,
#     272                 self._deadline,
# --> 273                 on_error=on_error,
#     274             )
#     275
#
# /opt/conda/lib/python3.6/site-packages/google/api_core/retry.py in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     200                     last_exc,
#     201                 ),
# --> 202                 last_exc,
#     203             )
#     204
#
# /opt/conda/lib/python3.6/site-packages/six.py in raise_from(value, from_value)
#
# RetryError: Deadline of 120.0s exceeded while calling functools.partial(functools.partial(<bound method _DataProxyConnection.api_request of <kaggle_gcp._DataProxyConnection object at 0x7fa590d17240>>, method='POST', path='/projects/kaggle-161607/jobs', data={'jobReference': {'jobId': 'd8f6dc31-88af-42e5-a254-cbd2b55fd152', 'projectId': 'kaggle-161607'}, 'configuration': {'query': {'useLegacySql': False, 'query': 'select top_terms from `patents-public-data.google_patents_research.publications` where ARRAY_LENGTH(top_terms) > 0 limit 10'}}})), last exception: 429 POST https://dp.kaggle.net/bigquery/v2/projects/kaggle-161607/jobs: Quota exceeded

# %%
top_terms_all = result['top_terms']

# %%
terms = [term for term in top_terms_all]

# %%
freq = {} 
for sublist in terms:
    for item in sublist:
        if (item in freq):
            freq[item] +=1
        else:
            freq[item] = 1

# %%
sorted(freq)

# %%
# sorted(freq.iteritems(), key = lambda x : x[1])
import operator
import collections
sorted(freq.items(), key=operator.itemgetter(1), reverse=True)
# collections.OrderedDict(freq)
# Out:
# [('method', 398),
#  ('cells', 88),
#  ('cell', 58),
#  ('characterized', 54),
#  ('method according', 51),
#  ('step', 51),
#  ('protein', 51),
#  ('treatment', 48),
#  ('subject', 44),
#  ('sample', 41),
#  ('compound', 40),
#  ('gene', 39),
#  ('composition', 38),
#  ('seq id', 36),
#  ('water', 34),
#  ('solution', 33),
#  ('process', 33),
#  ('patient', 33),
#  ('ml', 32),
#  ('according', 32),
#  ('expression', 32),
#  ('system', 31),
#  ('mg', 30),
#  ('concentration', 30),
#  ('activity', 29),
#  ('metal', 29),
#  ('group', 29),
#  ('nucleic acid', 28),
#  ('determining', 27),
#  ('disease', 26),
#  ('material', 25),
#  ('patients', 25),
#  ('information', 23),
#  ('present invention', 22),
#  ('surface', 21),
#  ('agent', 21),
#  ('level', 20),
#  ('example', 19),
#  ('cancer', 19),
#  ('non', 19),
#  ('data', 19),
#  ('lt', 19),
#  ('nanoparticles', 18),
#  ('sequence', 18),
#  ('plant', 17),
#  ('user', 17),
#  ('formula', 17),
#  ('particles', 17),
#  ('amount', 16),
#  ('acid', 16),
#  ('temperature', 16),
#  ('tumor', 16),
#  ('selected', 16),
#  ('polymer', 16),
#  ('inhibitor', 16),
#  ('group consisting', 15),
#  ('plurality', 15),
#  ('use', 15),
#  ('compounds', 15),
#  ('substrate', 15),
#  ('layer', 15),
#  ('β', 14),
#  ('content', 14),
#  ('anti', 14),
#  ('model', 14),
#  ('gt', 14),
#  ('structure', 14),
#  ('dose', 14),
#  ('amino acid', 14),
#  ('polypeptide', 14),
#  ('human', 14),
#  ('medium', 13),
#  ('blood', 13),
#  ('peptide', 13),
#  ('mm', 13),
#  ('dna', 13),
#  ('electrode', 13),
#  ('tissue', 13),
#  ('days', 13),
#  ('methods', 13),
#  ('catalyst', 13),
#  ('value', 13),
#  ('mixture', 12),
#  ('reaction', 12),
#  ('soil', 12),
#  ('hours', 12),
#  ('animal', 12),
#  ('diagnosis', 12),
#  ('complex', 12),
#  ('risk', 12),
#  ('individual', 12),
#  ('fluid', 12),
#  ('invention', 12),
#  ('proteins', 12),
#  ('antigen', 11),
#  ('test', 11),
#  ('means', 11),
#  ('number', 11),
#  ('nano', 11),
#  ('analysis', 11),
#  ('carbon', 11),
#  ('table', 11),
#  ('device', 11),
#  ('genes', 11),
#  ('skin', 11),
#  ('culture', 10),
#  ('kit', 10),
#  ('bacteria', 10),
#  ('enzyme', 10),
#  ('volume', 10),
#  ('extract', 10),
#  ('matrix', 10),
#  ('based', 10),
#  ('day', 10),
#  ('strain', 10),
#  ('substance', 10),
#  ('serum', 10),
#  ('oxide', 10),
#  ('film', 10),
#  ('infection', 10),
#  ('comprises', 10),
#  ('embodiments', 10),
#  ('kg', 10),
#  ('leu', 9),
#  ('hiv', 9),
#  ('antibody', 9),
#  ('receptor', 9),
#  ('molecules', 9),
#  ('coating', 9),
#  ('apparatus', 9),
#  ('degree', 9),
#  ('binding', 9),
#  ('organic', 9),
#  ('computer', 9),
#  ('acid sequence', 9),
#  ('preferably', 9),
#  ('measurement', 9),
#  ('state', 9),
#  ('response', 9),
#  ('unit', 9),
#  ('drug', 8),
#  ('production', 8),
#  ('beta', 8),
#  ('presence', 8),
#  ('il', 8),
#  ('muscle', 8),
#  ('cm', 8),
#  ('time', 8),
#  ('form', 8),
#  ('fe', 8),
#  ('vector', 8),
#  ('target', 8),
#  ('ratio', 8),
#  ('liver', 8),
#  ('hydrogen', 8),
#  ('oxygen', 8),
#  ('mammal', 8),
#  ('ii', 8),
#  ('species', 8),
#  ('used', 8),
#  ('plants', 8),
#  ('region', 8),
#  ('liquid', 8),
#  ('energy', 7),
#  ('derivative', 7),
#  ('type', 7),
#  ('promoter', 7),
#  ('cd4', 7),
#  ('composite', 7),
#  ('minutes', 7),
#  ('nm', 7),
#  ('component', 7),
#  ('carrier', 7),
#  ('growth', 7),
#  ('α', 7),
#  ('phase', 7),
#  ('set', 7),
#  ('weight', 7),
#  ('source', 7),
#  ('assay', 7),
#  ('probe', 7),
#  ('administering', 7),
#  ('urine', 7),
#  ('specific', 7),
#  ('administered', 7),
#  ('pain', 7),
#  ('flow', 7),
#  ('particle', 7),
#  ('methyl', 7),
#  ('ch', 7),
#  ('insulin', 7),
#  ('ligand', 7),
#  ('gel', 7),
#  ('pro', 7),
#  ('measuring', 7),
#  ('database', 7),
#  ('element', 6),
#  ('levels', 6),
#  ('virus', 6),
#  ('resistant', 6),
#  ('laser', 6),
#  ('teeth', 6),
#  ('samples', 6),
#  ('radiation', 6),
#  ('interaction', 6),
#  ('shell', 6),
#  ('light', 6),
#  ('equation', 6),
#  ('ala', 6),
#  ('gly', 6),
#  ('val', 6),
#  ('dye', 6),
#  ('range', 6),
#  ('resistance', 6),
#  ('domain', 6),
#  ('includes', 6),
#  ('preparation', 6),
#  ('further', 6),
#  ('oil', 6),
#  ('alcohol', 6),
#  ('mice', 6),
#  ('mir', 6),
#  ('administration', 6),
#  ('nitrogen', 6),
#  ('compositions', 6),
#  ('embodiment', 6),
#  ('acid molecule', 6),
#  ('ser', 6),
#  ('sequences', 6),
#  ('signal', 6),
#  ('therapy', 6),
#  ('evaluation', 6),
#  ('rna', 6),
#  ('body', 6),
#  ('learning', 6),
#  ('points', 6),
#  ('standard', 5),
#  ('obtained', 5),
#  ('product', 5),
#  ('vitamin', 5),
#  ('properties', 5),
#  ('color', 5),
#  ('predicting', 5),
#  ('severity', 5),
#  ('input', 5),
#  ('extraction', 5),
#  ('transition metal', 5),
#  ('fish', 5),
#  ('function', 5),
#  ('high', 5),
#  ('pcr', 5),
#  ('core', 5),
#  ('screening', 5),
#  ('porous', 5),
#  ('precursor', 5),
#  ('provided', 5),
#  ('stress', 5),
#  ('cu', 5),
#  ('flap', 5),
#  ('yl', 5),
#  ('erythrocytes', 5),
#  ('phosphorylation', 5),
#  ('inhibitors', 5),
#  ('brain', 5),
#  ('pressure', 5),
#  ('metal oxide', 5),
#  ('mirna', 5),
#  ('part', 5),
#  ('biological sample', 5),
#  ('configured', 5),
#  ('recited', 5),
#  ('derived', 5),
#  ('graphene', 5),
#  ('alkyl', 5),
#  ('network', 5),
#  ('scale', 5),
#  ('distribution', 5),
#  ('female', 5),
#  ('activation', 5),
#  ('copper', 5),
#  ('children', 5),
#  ('containing', 5),
#  ('solvent', 5),
#  ('gas', 5),
#  ('chemical', 5),
#  ('tooth', 5),
#  ('detecting', 5),
#  ('prediction', 5),
#  ('mitochondrial', 5),
#  ('yeast', 5),
#  ('iron', 5),
#  ('ir', 5),
#  ('magnetic field', 4),
#  ('zeolite', 4),
#  ('feed', 4),
#  ('methanol', 4),
#  ('1h', 4),
#  ('food', 4),
#  ('ph', 4),
#  ('ca', 4),
#  ('fusion', 4),
#  ('less', 4),
#  ('process according', 4),
#  ('reagent', 4),
#  ('silver', 4),
#  ('added', 4),
#  ('heat', 4),
#  ('ultrasound', 4),
#  ('eggs', 4),
#  ('air', 4),
#  ('head', 4),
#  ('substituted', 4),
#  ('disorders', 4),
#  ('portions', 4),
#  ('determination', 4),
#  ('carbon atoms', 4),
#  ('ar', 4),
#  ('length', 4),
#  ('cell line', 4),
#  ('well', 4),
#  ('single', 4),
#  ('breeding', 4),
#  ('secretion', 4),
#  ('dispersion', 4),
#  ('inorganic', 4),
#  ('elements', 4),
#  ('plasma', 4),
#  ('glu', 4),
#  ('asp', 4),
#  ('tio', 4),
#  ('change', 4),
#  ('area', 4),
#  ('dendrimer', 4),
#  ('sodium', 4),
#  ('direction', 4),
#  ('effect', 4),
#  ('crystal', 4),
#  ('pregnancy', 4),
#  ('recurrence', 4),
#  ('complications', 4),
#  ('isolated', 4),
#  ('defined', 4),
#  ('property', 4),
#  ('dimensional', 4),
#  ('subjects', 4),
#  ('polynucleotide', 4),
#  ('channel', 4),
#  ('preparing', 4),
#  ('nanoparticle', 4),
#  ('doped', 4),
#  ('biomarker', 4),
#  ('output', 4),
#  ('diffusion', 4),
#  ('bone', 4),
#  ('biomarkers', 4),
#  ('location', 4),
#  ('associated', 4),
#  ('conditions', 4),
#  ('electrodes', 4),
#  ('set forth', 4),
#  ('mass', 4),
#  ('silica', 4),
#  ('prostate cancer', 4),
#  ('release', 4),
#  ('wound', 4),
#  ('chamber', 4),
#  ('coated', 4),
#  ('candidate', 4),
#  ('neurons', 4),
#  ('eye', 4),
#  ('irradiation', 4),
#  ('parameters', 4),
#  ('estimated', 4),
#  ('support', 4),
#  ('aqueous solution', 4),
#  ('fragment', 4),
#  ('bis', 4),
#  ('density', 4),
#  ('motor', 4),
#  ('organism', 4),
#  ('derivatives', 4),
#  ('animals', 4),
#  ('side', 4),
#  ('normal', 4),
#  ('plate', 4),
#  ('steel', 4),
#  ('anaerobic', 4),
#  ('titanium', 4),
#  ('classifier', 4),
#  ('molecular', 4),
#  ('producing', 4),
#  ('breast cancer', 4),
#  ('uses', 4),
#  ('same', 4),
#  ('iii', 4),
#  ('reference', 4),
#  ('process feed', 4),
#  ('pg', 4),
#  ('suspension', 3),
#  ('microwave', 3),
#  ('poultry', 3),
#  ('weight percent', 3),
#  ('organic solvent', 3),
#  ('ethanol', 3),
#  ('agar', 3),
#  ('molecular weight', 3),
#  ('immunoglobulin', 3),
#  ('calcium', 3),
#  ('oxidation', 3),
#  ('pi', 3),
#  ('member', 3),
#  ('mutant', 3),
#  ('sr', 3),
#  ('transcription', 3),
#  ('ag', 3),
#  ('conductivity', 3),
#  ('meat', 3),
#  ('fractions', 3),
#  ('assessment', 3),
#  ('adipose tissue', 3),
#  ('fragments', 3),
#  ('control', 3),
#  ('fixing', 3),
#  ('rate', 3),
#  ('page', 3),
#  ('front', 3),
#  ('cover', 3),
#  ('assessing', 3),
#  ('min', 3),
#  ('carried out', 3),
#  ('detection', 3),
#  ('red', 3),
#  ('absence', 3),
#  ('invention relates', 3),
#  ('development', 3),
#  ('activities', 3),
#  ('disclosed', 3),
#  ('create', 3),
#  ('biological', 3),
#  ('determined', 3),
#  ('emotional', 3),
#  ('character', 3),
#  ('fluorescence', 3),
#  ('nanotubes', 3),
#  ('carbon nanotubes', 3),
#  ('ige', 3),
#  ('fiber', 3),
#  ('fibers', 3),
#  ('absorbance', 3),
#  ('lung', 3),
#  ('calculating', 3),
#  ('name', 3),
#  ('zinc', 3),
#  ('cholesterol', 3),
#  ('preparation method', 3),
#  ('lys', 3),
#  ('ile', 3),
#  ('fermentation', 3),
#  ('section', 3),
#  ('cross', 3),
#  ('design', 3),
#  ('optimization', 3),
#  ('solar cell', 3),
#  ('module', 3),
#  ('increased', 3),
#  ('membrane', 3),
#  ('sheet', 3),
#  ('position', 3),
#  ('zn', 3),
#  ('including', 3),
#  ('measured', 3),
#  ('φ', 3),
#  ('composition according', 3),
#  ('interest', 3),
#  ('incubation', 3),
#  ('occurrence', 3),
#  ('antigens', 3),
#  ('vegf', 3),
#  ('identification', 3),
#  ('organic compounds', 3),
#  ('serine', 3),
#  ('steps', 3),
#  ('media', 3),
#  ('dynamic', 3),
#  ('ps', 3),
#  ('cultured', 3),
#  ('label', 3),
#  ('antibodies', 3),
#  ('pc', 3),
#  ('recipient', 3),
#  ('local', 3),
#  ('starch', 3),
#  ('iridium', 3),
#  ('nerve', 3),
#  ('hydrogel', 3),
#  ('sub', 3),
#  ('cognitive', 3),
#  ('electrical', 3),
#  ('score', 3),
#  ('weeks', 3),
#  ('phenotype', 3),
#  ('ammonia', 3),
#  ('prostate', 3),
#  ('sb', 3),
#  ('point', 3),
#  ('disposed', 3),
#  ('μm', 3),
#  ('stroke', 3),
#  ('materials', 3),
#  ('antibiotic', 3),
#  ('energy conversion', 3),
#  ('molecule', 3),
#  ('providing', 3),
#  ('attributes', 3),
#  ('bulk', 3),
#  ('groups', 3),
#  ('disorder', 3),
#  ('composites', 3),
#  ('message', 3),
#  ('agents', 3),
#  ('factor', 3),
#  ('ischemia', 3),
#  ('thr', 3),
#  ('asn', 3),
#  ('erythrocyte', 3),
#  ('ccr5', 3),
#  ('infected', 3),
#  ('oocytes', 3),
#  ('vitro', 3),
#  ('embryo', 3),
#  ('integrin', 3),
#  ('pharmaceutical composition', 3),
#  ('seeds', 3),
#  ('combinations', 3),
#  ('ion', 3),
#  ('age', 3),
#  ('car', 3),
#  ('acute', 3),
#  ('represents', 3),
#  ('surface tension', 3),
#  ('wnt', 3),
#  ('pathway', 3),
#  ('constraints', 3),
#  ('sirna', 3),
#  ('mutation', 3),
#  ('duration', 3),
#  ('paper', 3),
#  ('lignin', 3),
#  ('wood', 3),
#  ('spectrum', 3),
#  ('metal ion', 3),
#  ('lead', 3),
#  ('block', 3),
#  ('sensor', 3),
#  ('syndrome', 3),
#  ('index', 3),
#  ('financial', 3),
#  ('bound', 3),
#  ('bit', 3),
#  ('array', 3),
#  ('library', 3),
#  ('vaccine', 3),
#  ('tumour', 3),
#  ('arg', 3),
#  ('size', 3),
#  ('reporter gene', 3),
#  ('frequency', 3),
#  ('physical', 3),
#  ('active', 3),
#  ('metabolite', 3),
#  ('fingers', 3),
#  ('picture', 3),
#  ('education', 3),
#  ('leukocytes', 3),
#  ('amine', 3),
#  ('changes', 3),
#  ('androgen', 3),
#  ('heart failure', 3),
#  ('dielectric', 3),
#  ('accuracy', 3),
#  ('tomato', 3),
#  ('height', 3),
#  ('initial', 3),
#  ('cooling', 3),
#  ('microorganisms', 3),
#  ('adjacent', 3),
#  ('current', 3),
#  ('formed', 3),
#  ('antenna', 3),
#  ('de', 3),
#  ('resin', 3),
#  ('performed', 3),
#  ('processing', 3),
#  ('units', 3),
#  ('regeneration', 3),
#  ('wt', 3),
#  ('class', 3),
#  ('multi', 3),
#  ('cases', 3),
#  ('environment', 3),
#  ('microorganism', 3),
#  ('modified', 3),
#  ('mammalian', 3),
#  ('porphyrin', 3),
#  ('transport', 3),
#  ('correlation', 3),
#  ('fusion protein', 3),
#  ('recombinant', 3),
#  ('optical', 3),
#  ('learner', 3),
#  ('breast', 3),
#  ('ft', 3),
#  ('di', 3),
#  ('nucleotide sequence', 3),
#  ('fluorescent', 3),
#  ('concentrations', 3),
#  ('strains', 3),
#  ('phenyl', 3),
#  ('p53', 3),
#  ('complexes', 3),
#  ('islets', 3),
#  ('muscles', 3),
#  ('exercise', 3),
#  ('image', 3),
#  ('study', 3),
#  ('atoms', 3),
#  ('embryos', 3),
#  ('2h', 3),
#  ('treating', 3),
#  ('titer', 2),
#  ('meal', 2),
#  ('sperm', 2),
#  ('apolipoprotein', 2),
#  ('blood serum', 2),
#  ('cyanidin', 2),
#  ('indicator', 2),
#  ('buffer', 2),
#  ('ovulation', 2),
#  ('vacuum', 2),
#  ('low', 2),
#  ('separation', 2),
#  ('udp', 2),
#  ('galnac', 2),
#  ('purified', 2),
#  ('land', 2),
#  ('bee', 2),
#  ('positioned', 2),
#  ('sized', 2),
#  ('cis', 2),
#  ('detergent', 2),
#  ('rapamycin', 2),
#  ('bi', 2),
#  ('cd8', 2),
#  ('estrogen', 2),
#  ('synthesis', 2),
#  ('th', 2),
#  ('uranium', 2),
#  ('column', 2),
#  ('hybrids', 2),
#  ('tumors', 2),
#  ('ablation', 2),
#  ('small', 2),
#  ('clinical course', 2),
#  ('trees', 2),
#  ('interval', 2),
#  ('fields', 2),
#  ('term', 2),
#  ('foot', 2),
#  ('selection', 2),
#  ('alfalfa', 2),
#  ('acidity', 2),
#  ('iir', 2),
#  ('filling materials', 2),
#  ('times', 2),
#  ('cord blood', 2),
#  ('navel', 2),
#  ('abdominal wall', 2),
#  ('abdominal', 2),
#  ('incision', 2),
#  ('quality', 2),
#  ('heart', 2),
#  ('trifluoromethyl', 2),
#  ('pancreas', 2),
#  ('dried', 2),
#  ('functionalized', 2),
#  ('rice bran', 2),
#  ('fraction', 2),
#  ('trap', 2),
#  ('habitat', 2),
#  ('men', 2),
#  ('formulation', 2),
#  ('matter', 2),
#  ('pages', 2),
#  ('nutrient', 2),
#  ('beads', 2),
#  ('conductive', 2),
#  ('nanocomposite', 2),
#  ('corresponding', 2),
#  ('poly', 2),
#  ('electric', 2),
#  ('alkyl group', 2),
#  ('cement', 2),
#  ('aggregate', 2),
#  ('pp', 2),
#  ('hbv', 2),
#  ('hepatitis', 2),
#  ('tree', 2),
#  ('wall', 2),
#  ('pine', 2),
#  ('radical', 2),
#  ('antioxidant', 2),
#  ('primer', 2),
#  ('calculated', 2),
#  ('series', 2),
#  ('ginsenoside', 2),
#  ('allergic', 2),
#  ('ol', 2),
#  ('nfat', 2),
#  ('nanofibers', 2),
#  ('diameter', 2),
#  ('hybrid', 2),
#  ('adsorbent', 2),
#  ('thallium', 2),
#  ('nanostructure', 2),
#  ('selenium', 2),
#  ('carnitine', 2),
#  ('cardiovascular complications', 2),
#  ('stiffness', 2),
#  ('overweight', 2),
#  ('bacillus subtilis', 2),
#  ('shape', 2),
#  ('drug delivery', 2),
#  ('delivery system', 2),
#  ('exposure', 2),
#  ('estimation', 2),
#  ('metal nanoparticles', 2),
#  ('sensitized solar', 2),
#  ('da', 2),
#  ('toxin', 2),
#  ('toxicity', 2),
#  ('neck', 2),
#  ('citrus', 2),
#  ('parts', 2),
#  ('provides', 2),
#  ('piezoelectric', 2),
#  ('performance', 2),
#  ('consisting', 2),
#  ('platform', 2),
#  ('sheets', 2),
#  ('occlusion', 2),
#  ('modeling', 2),
#  ('ba', 2),
#  ('ti', 2),
#  ('vegetation', 2),
#  ('colon', 2),
#  ('cut', 2),
#  ('vessels', 2),
#  ('artery', 2),
#  ('types', 2),
#  ('pregnant', 2),
#  ('key', 2),
#  ('ifn', 2),
#  ('quantitative analysis', 2),
#  ('slope', 2),
#  ('crown', 2),
#  ('reduction', 2),
#  ('period', 2),
#  ('gene expression', 2),
#  ('bacterium', 2),
#  ('tests', 2),
#  ('influenza', 2),
#  ('iodine', 2),
#  ('growth factor', 2),
#  ('amino acids', 2),
#  ('fluoro', 2),
#  ('integrated', 2),
#  ('cassette', 2),
#  ('sp', 2),
#  ('glucose', 2),
#  ('contamination', 2),
#  ('body fluid', 2),
#  ('culture medium', 2),
#  ('diabetic', 2),
#  ('container', 2),
#  ('up', 2),
#  ('business', 2),
#  ('cages', 2),
#  ('upper', 2),
#  ('members', 2),
#  ('secured', 2),
#  ('application', 2),
#  ('gas mixture', 2),
#  ('measurements', 2),
#  ('disulfide', 2),
#  ('oa', 2),
#  ('regimen', 2),
#  ('mercury', 2),
#  ('hydrophilic polymer', 2),
#  ('atp', 2),
#  ('swelling', 2),
#  ('anesthetic', 2),
#  ('soft tissue', 2),
#  ('social', 2),
#  ('high fat', 2),
#  ('likelihood', 2),
#  ('monoclonal antibody', 2),
#  ('hsa', 2),
#  ('microrna', 2),
#  ('5p', 2),
#  ('microbiome', 2),
#  ('functional', 2),
#  ('generating', 2),
#  ('cardiovascular disease', 2),
#  ('future', 2),
#  ('power', 2),
#  ('inh', 2),
#  ('surfactant', 2),
#  ('ligands', 2),
#  ('manufacturing', 2),
#  ('peripheral nerve', 2),
#  ('amp', 2),
#  ('therapeutic agent', 2),
#  ('osteoporosis', 2),
#  ('particular', 2),
#  ('movement', 2),
#  ('mirnas', 2),
#  ('shock', 2),
#  ('greater', 2),
#  ('nf', 2),
#  ('doxorubicin', 2),
#  ('hybridization', 2),
#  ('game', 2),
#  ('card', 2),
#  ('reading', 2),
#  ('juice', 2),
#  ('titanium oxide', 2),
#  ('music', 2),
#  ('bio', 2),
#  ('electrochemical cell', 2),
#  ('pd', 2),
#  ('thin film', 2),
#  ('supercapacitor', 2),
#  ('percent', 2),
#  ('vascular', 2),
#  ('cnt', 2),
#  ('lower', 2),
#  ('aryl', 2),
#  ('images', 2),
#  ('tolerance', 2),
#  ('shellfish', 2),
#  ('crabs', 2),
#  ('comprise', 2),
#  ('immunogenic composition', 2),
#  ('npm', 2),
#  ('semiconductor photocatalyst', 2),
#  ('chain', 2),
#  ('segment', 2),
#  ('stomach', 2),
#  ('incubator', 2),
#  ('nest', 2),
#  ('site', 2),
#  ('participant', 2),
#  ('decision making', 2),
#  ('master', 2),
#  ('band', 2),
#  ('pyridine', 2),
#  ('tego', 2),
#  ('graphite', 2),
#  ('graphite oxide', 2),
#  ('pmma', 2),
#  ('go', 2),
#  ('surface area', 2),
#  ('grid', 2),
#  ('indication', 2),
#  ('linked', 2),
#  ('attribute', 2),
#  ('chitosan', 2),
#  ('ceramic', 2),
#  ('ynyl', 2),
#  ('aggregates', 2),
#  ('diamond', 2),
#  ('pt', 2),
#  ('substances', 2),
#  ('nematode', 2),
#  ('chromosome', 2),
#  ('radioisotope', 2),
#  ('na', 2),
#  ('pulse', 2),
#  ('coreceptor', 2),
#  ('cxcr4', 2),
#  ('oocyte', 2),
#  ('immature', 2),
#  ('codon', 2),
#  ('symptoms', 2),
#  ('fatty acids', 2),
#  ('depression', 2),
#  ('aβ', 2),
#  ('soluble', 2),
#  ('dimethyl', 2),
#  ('id', 2),
#  ('catalytic', 2),
#  ('damage', 2),
#  ('storage', 2),
#  ('diesel fuel', 2),
#  ('antibacterial', 2),
#  ('probability', 2),
#  ('subunit', 2),
#  ('β3', 2),
#  ('β2', 2),
#  ('voltage', 2),
#  ('cos', 2),
#  ('mek inhibitor', 2),
#  ('mek', 2),
#  ('interventions', 2),
#  ('standards', 2),
#  ('drying', 2),
#  ('objectives', 2),
#  ('blood sample', 2),
#  ('child', 2),
#  ('obesity', 2),
#  ('years', 2),
#  ('peg', 2),
#  ('portion', 2),
#  ('skills', 2),
#  ('alloy', 2),
#  ('nitric oxide', 2),
#  ('white', 2),
#  ('pre', 2),
#  ('male', 2),
#  ('activator', 2),
#  ('present', 2),
#  ('photoelectric conversion', 2),
#  ('electron', 2),
#  ('canceled', 2),
#  ('simulated', 2),
#  ('medical device', 2),
#  ('mn', 2),
#  ('hydrogen peroxide', 2),
#  ('manganese', 2),
#  ('aqueous', 2),
#  ('during', 2),
#  ('port', 2),
#  ('noise', 2),
#  ('contaminated', 2),
#  ('oxide layer', 2),
#  ('forming', 2),
#  ('igg', 2),
#  ('ions', 2),
#  ('decoder', 2),
#  ('blood glucose', 2),
#  ('temporary', 2),
#  ('variables', 2),
#  ('factors', 2),
#  ('peptides', 2),
#  ('converting enzyme', 2),
#  ('described', 2),
#  ('ability', 2),
#  ('retinoic acid', 2),
#  ('mrna', 2),
#  ('personal', 2),
#  ('diagnostic', 2),
#  ('tau', 2),
#  ('variant', 2),
#  ('under', 2),
#  ('quantum', 2),
#  ('potential', 2),
#  ('base', 2),
#  ('months', 2),
#  ('iv', 2),
#  ('hydrocarbon', 2),
#  ('metabolites', 2),
#  ('callus', 2),
#  ('mobility', 2),
#  ('hz', 2),
#  ('sio', 2),
#  ('clay', 2),
#  ('reducing', 2),
#  ('velocity', 2),
#  ('ƒ', 2),
#  ('person', 2),
#  ('bone implant', 2),
#  ('type ii', 2),
#  ('manufacturing method', 2),
#  ('amino', 2),
#  ('inflammatory diseases', 2),
#  ('intoxication', 2),
#  ('case', 2),
#  ('increase', 2),
#  ('staining', 2),
#  ('identifying', 2),
#  ('titration', 2),
#  ('outer', 2),
#  ('rotary', 2),
#  ('body weight', 2),
#  ('females', 2),
#  ('condition', 2),
#  ('pancreatic', 2),
#  ('mmol', 2),
#  ('rhodium', 2),
#  ('en', 2),
#  ...]
